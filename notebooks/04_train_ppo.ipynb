# %% [markdown]
# # 04 — Train PPO (SB3)

# %%
# !python -m packages.rl.train_ppo \
    --symbol BTC/USDT \
    --timeframe 1d \
    --start 2021-01-01 \
    --end 2023-01-01
# Out:
# [trainer] cfg: TrainConfig(symbol='BTC/USDT', timeframe='1d', start='2021-01-01', end='2023-01-01', window=128, total_timesteps=200000, save_path=None, seed=1990934671, tb=False, n_steps=None, batch_size=None, log_interval=None, policy='MlpPolicy', policy_kwargs={}, env_class=None, env_kwargs={}, use_wandb=False, wandb_project='rl-bybit-ppo', wandb_run_name=None)
# [trainer] rows_raw=548  range=(2021-07-01 00:00:00+00:00 .. 2023-01-01 00:00:00+00:00)
# [trainer] rows_after_features=548  max_env_steps=547  requested=200000  effective=547
# /Users/andrewgrit/code/quant/rl-bybit-ppo/.venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/vec_monitor.py:44: UserWarning: The environment is already wrapped with a `Monitor` wrapperbut you are wrapping it with a `VecMonitor` wrapper, the `Monitor` statistics will beoverwritten by the `VecMonitor` ones.
#   warnings.warn(
# [trainer] auto params: n_steps=91, batch_size=64, log_interval=1, iters≈6
# Using cpu device
# ...

# %%
# !python -m packages.rl.backtest_ppo \
    --symbol BTC/USDT \
    --timeframe 1d \
    --start 2023-01-01 \
    --end 2024-01-01 \
    --model_path models/ppo-BTCUSDT-1d.zip
# Out:
# Validation results (2023-01-01 → 2024-01-01):
# total_reward: -3.014154084682467
# mean_reward: -0.00825795639639032
# n_steps: 365
